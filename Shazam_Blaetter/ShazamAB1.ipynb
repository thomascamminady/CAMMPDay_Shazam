# %% [markdown]
# # SHAZAM - Aufgabenblatt 1: Einen Ton mathematisch modellieren
# ## Einleitung
# Wir Menschen hören mit den Ohren, indem das Trommelfell Schallwellen aufnimmt. Schallwellen sind nichts anderes als Druckschwankungen in der Luft. Diese Druckschwankungen sind in der Regel sehr komplex und schwer zu modellieren, aber es gibt auch relativ simple Geräusche. Das wohl einfachste Geräusch ist der (reine) Ton, dessen erzeugende Schwingung durch eine Sinusfunktion beschrieben werden kann.
#
# Auf diesem Aufgabenblatt wollen wir uns genauer damit beschäftigen, wie reine Töne mathematisch modelliert werden: Ein Ton $g$ ist nichts anderes als eine Sinusschwingung, deren Amplitude die Lautstärke des Tons festlegt und deren Frequenz der Tonhöhe entspricht. Er kann durch die Gleichung
#                                                                                                                                            $$g(t) = A \cdot sin(2 \cdot π \cdot f \cdot  t)$$
#                                                                                                                                      beschrieben werden. Hier seht ihr den (Teil-)Graphen einer Sinusschwingung:
# ![Stimmgabel.png](attachment:Stimmgabel.png)
# Dabei steht
# - $t$ für die **Zeit**.
# - $A$ für die **Amplitude**. Diese gibt die maximale Auslenkung der Schwingung aus der Nulllage an. Physikalisch entspricht sie der **Lautstärke** des Tons. Je größer die Amplitude, desto lauter der Ton.
# - $f$ für die **Frequenz**. Die Frequenz gibt die Anzahl der Schwingungen pro Sekunde an. Die Einheit der Frequenz ist Hertz [Hz = 1/s]. Sie ist der Kehrwert der **Periodendauer** $T$ ($f = 1/T$). Diese bezeichnet den zeitlichen Abstand zweier aufeinander folgender Maxima (oder auch zweier aufeinander folgender Minima) und besitzt folglich die Einheit Sekunde [s]. Dies bedeutet, je größer die Frequenz $f$, desto kleiner die Periodendauer - also der Abstand zwischen den Maxima.  Physikalisch entspricht die Frequenz der **Tonhöhe**.
#
# Die von Instrumenten und der menschlichen Stimme erzeugten Geräusche setzen sich aus vielen verschiedenen Tönen unterschiedlicher Frequenzen zusammen. Die genaue Zusammensetzung der Frequenzen bestimmt zwar den wahrnehmbaren Klang eines Geräuschs, allerdings ist das menschliche Gehör nicht in der Lage, die einzelnen Frequenzen herauszuhören. Mit Hilfe eines Computers oder eines Oszilloskops können diese jedoch sichtbar gemacht werden. Töne sind also deshalb von so großer Bedeutung, weil jedes beliebige Geräusch - zumindest in guter Nährung - als (ggf. sehr komplexe) Summe verschiedener Tönen dargestellt werden kann.
#
# *Damit dieses Arbeitsblatt funktioniert, musst du als erstes den folgenden Code ausführen. Klicke dazu auf das Code Feld und drücke auf "Run" (oder drücke Shift + Enter).*

# %%
# Hier nichts ändern
include("./code/ShazamTests.jl")
# Out:
# WARNING: replacing module Shazam.
# Main.Shazam

# %% [markdown]
# ## Aufgabe 1a)
#
# Schaue dir den folgenden Graphen, der einen Sinuston auf dem Intervall [0,  0.1] zeigt, genau an:
# ![sinuston.png](attachment:sinuston.png)
# - Welchen Wert hat die Amplitude dieses Tons?
# - Welchen Wert hat die Frequenz dieses Tons?
#
# *Ersetze im folgenden Code `NaN` durch die Amplitude bzw. die Frequenz des obigen Tons. Klicke danach auf den "Run" Button (oder drücke Shift + Enter). Daraufhin kannst du den oben abgebildeten Sinuston abspielen lassen. Danach wird der Sinuston geplottet, der die von dir eingegebene Amplitude und Frequenz besitzt. Vergleiche die beiden Graphen. Beachte dabei die Achsenbeschriftung. Falls die Töne nicht identisch sind, bekommst du eine Fehlermeldung. Korrigiere deine Eingabe in diesem Fall mithilfe der Graphen.*

# %%
amplitude = 1; # Ersetze 'NaN' durch die Amplitude des oben abgebildeten Tons
frequenz = 200; # Ersetze 'NaN' durch die Frequenz des oben abgebildeten Tons

# Ab hier nichts mehr ändern
Shazam.AB1A1aPlay()
Shazam.AB1Aufgabe1a(amplitude,frequenz)
# Out:
# <audio controls="controls" {autoplay}>
# <source src="SinustonAB1A1a.wav" type="audio/wav" />
# Your browser does not support the audio element.
# </audio>

# %% [markdown]
# ## Aufgabe 1b)
# Wir wissen bereits: Je größer die Amplitude gewählt wird, desto lauter wird der Ton wahrgenommen.
#
# Überlege dir wie du die Amplitude ändern musst, damit der neue Ton leiser bzw. lauter wird als der aus Aufgabe 1a).
#
# *Ersetze im folgenden Code `NaN` durch Zahlen, sodass der Ton mit Amplitude `amplitude_leiser` leiser ist als der aus Aufgabe 1a) und der Ton mit Amplitude `amplitude_lauter` lauter ist als der aus Aufgabe 1a).
# Klicke dann auf den "Run" Button, um die drei Töne abspielen zu können. Zuerst den aus Teil a), dann den mit `amplitude_leiser` und dann den mit `amplitude_lauter`. Danach werden die Töne geplottet. Der Ton aus Teil a) ist in Blau eingezeichnet, der Ton mit Amplitude `amplitude_leiser` in Orange und der mit `amplitude_lauter` in Grün. Falls deine Eingabe fehlerhaft ist, bekommst du eine Warnung. Korrigiere dich selbst mithilfe der Töne und des Graphen.*
#
# **Hinweis: Diese Aufgabe besitzt mehr als eine richtige Lösung. Probiere gerne verschiedene Lösungen aus und siehe dir die Ergebnisse an.**

# %%
amplitude_leiser = 0.5; # Ersetze 'NaN' durch einen Wert, sodass der Ton im Vergleich zu Teil a leiser wird
amplitude_lauter = 3; # Ersetze 'NaN' durch einen Wert, sodass der Ton im Vergleich zu Teil a lauter wird

# Ab hier nichts mehr ändern
Shazam.AB1A1bPlay(amplitude_leiser, amplitude_lauter)
Shazam.AB1Aufgabe1b(amplitude,amplitude_leiser,amplitude_lauter)
# Out:
# <audio controls="controls" {autoplay}>
# <source src="SinustonAB1A1b.wav" type="audio/wav" />
# Your browser does not support the audio element.
# </audio>

# %% [markdown]
# ## Aufgabe 1c)
# ### Teil 1
# Bisher war die Amplitude des Tons über die Zeit konstant. Nun wollen wir die Lautstärke des Tons über die Zeit ändern.
#
# Überlege dir, wie die Amplitude $A$ in Abhängigkeit der Zeit $t$ gewählt werden muss, damit die Lautstärke zum Zeitpunkt $t=0$ den Wert Null hat und lineares Wachstum in $t$ besitzt. Du kennst bereits viele Funktionen mit linearem Wachstum, nämlich alle ansteigenden Geraden.
#
# *Ersetze im folgenden Code `NaN` durch einen Ausdruck in $t$, der lineares Wachstum in $t$ beschreibt und zum Zeitpunkt $t = 0$ den Wert Null hat. Klicke anschließend auf den "Run" Button, um dir deinen erzeugten Ton anzuhören und anzusehen. Falls deine Eingabe fehlerhaft ist, bekommst du eine Warnung angezeigt. Korrigiere deine Eingabe in diesem Fall.*
#
# **Hinweis: Falls du beim Lösen dieser Aufgabe Hilfe benötigst, siehe dir [Hilfekarte 1](./ShazamHilfekarte1.ipynb) an**

# %%
A(t) = t; # Ersetze 'NaN' durch einen Ausdruck in t, der lineares Wachstum in t beschreibt und bei t=0 den Wert Null hat

# Ab hier nichts mehr ändern
Shazam.AB1A1c1Play(A)
Shazam.AB1Aufgabe1c1(A)
# Out:
# <audio controls="controls" {autoplay}>
# <source src="SinustonAB1A1c1.wav" type="audio/wav" />
# Your browser does not support the audio element.
# </audio>

# %% [markdown]
# ### Teil 2
# Überlege dir, wie die Amplitude eines Tons gewählt werden muss, der folgende Bedingungen erfüllt:
# - Seine Amplitude wächst linear.
# - Bei t = 0 hat seine Amplitude den Wert 0.
# - Seine Amplitude wächst schneller als die des Tons aus Teil 1.
#
# *Ersetze im folgenden Code `NaN` durch einen Term in $t$, der die Amplitude eines Tons beschreibt, der die obigen drei Bedingungen erfüllt. Klicke anschließend auf "Run", um dir beide Töne anzuhören; den aus Teil 1 zuerst, dann den aus Teil 2. Danach werden beide Töne in Blau bzw. Orange geplottet. Falls deine Eingabe fehlerhaft ist, bekommst du eine Warnung. Korrigiere dich dann mithilfe der Abbildung und des Tons.*
#
# **Hinweis: Falls du beim Lösen dieser Aufgabe Hilfe benötigst, siehe dir [Hilfekarte 1](./ShazamHilfekarte1.ipynb) an**

# %%
A2(t) = 2t; # Ersetze 'NaN' durch einen Term in t, der die Amplitude eines Tons beschreibt, der die obigen drei Bedingungen erfüllt

# Ab hier nichts mehr ändern
Shazam.AB1A1c2Play(A,A2)
Shazam.AB1Aufgabe1c2(A,A2)
# Out:
# <audio controls="controls" {autoplay}>
# <source src="SinustonAB1A1c2.wav" type="audio/wav" />
# Your browser does not support the audio element.
# </audio>

# %% [markdown]
# ## Aufgabe 1d)
# Nun wollen wir einen Ton erzeugen, dessen Amplitude linear fällt und dessen Länge 1 s beträgt. Überlege dir dazu, wie die Amplitude eines Tons in Abhängigkeit von $t$ gewählt werden muss, damit diese linear fällt und bei $t = 1$ den Wert $0$ hat.
#
# *Ersetze im folgenden Code `NaN` durch einen Term, der die Amplitude eines Tons beschreibt, dessen Amplitude linear fällt und der 1 s lang ist. Das heißt, dessen Amplitude zum Zeitpunkt $t = 1$ den Wert Null hat. Klicke auf "Run", um den Ton anzusehen und anzuhören. Falls deine Eingabe fehlerhaft ist, bekommst du eine Warnung. Korrigiere dich in diesem Fall.*
#
# **Hinweis: Falls du beim Lösen dieser Aufgabe Hilfe benötigst, siehe dir [Hilfekarte 1](./ShazamHilfekarte1.ipynb) an**

# %%
A3(t) = 1-t; # Ersetze 'NaN' durch einen Term in t, der die Amplitude eines Tons beschreibt, der 1 s lang ist und dessen Amplitude linear fällt 

# Ab hier nichts mehr ändern
Shazam.AB1A1dPlay(A3)
Shazam.AB1Aufgabe1d(A3)
# Out:
# <audio controls="controls" {autoplay}>
# <source src="SinustonAB1A1d.wav" type="audio/wav" />
# Your browser does not support the audio element.
# </audio>

# %% [markdown]
# ## Aufgabe 2a)
# Bisher hatten alle betrachteten Töne eine Frequenz von 200 Hz. Nun werden wir dazu übergehen, nicht nur die Amplitude, sondern auch die Frequenz eines Tons zu ändern. Du weißt bereits: Je höher ein Ton klingt, desto höher ist seine Frequenz und desto kleiner ist seine Periodendauer. Betrachte den Ton
# $$ g(t) = \sin(F \cdot 200 \cdot 2\pi \cdot t), \ t \geq 0,$$
# dessen Frequenz von $F$ abhängt. Überlege dir, wie $F$ zu wählen ist, damit der obige Ton g höher bzw. tiefer klingt, als der Referenzton
# $$\sin(200 \cdot 2\pi \cdot t), \ t \geq 0.$$
# $F$ soll dabei in beiden Fällen zwischen 0 und 6 liegen.
#
# *Ersetze im folgenden Code `NaN` durch einen Wert zwischen 0 und 6, sodass der Ton $g$ (s.o.) mit dem von dir gewählten $F$ höher bzw. tiefer klingt als der Referenzton. Klicke anschließend auf "Run", um die drei Töne abzuspielen: Erst den Referenzton, dann den Ton mit $F = $ `F_hoeher`, zum Schluss den Ton mit $F = $ `F_tiefer`. Danach werden die drei Töne auf dem Intervall $[0,0.1]$ gezeichnet; der Referenzton in Blau, der Ton mit `F_hoeher` in Orange und der mit `F_tiefer` in Grün. Falls deine Eingabe fehlerhaft war, bekommst du eine Warnung. Korrigiere dich in diesem Fall.*
#
# **Hinweis: Diese Aufgabe besitzt mehr als eine richtige Lösung. Probiere gerne verschiedene Lösungen aus und höre dir die Ergebnisse an.**

# %%
F_hoeher = 2; # Ersetze 'NaN' durch einen geeigneten Wert für F, sodass der Ton g (s.o.) höher klingt, als der Referenzton

F_tiefer = 0.7; # Ersetze 'NaN' durch einen geeigneten Wert für F, sodass der Ton g (s.o) tiefer klingt, als der Referenzton

# Ab hier nichts mehr Ändern
Shazam.AB1A2aPlay(F_hoeher,F_tiefer)
Shazam.AB1Aufgabe2a(F_hoeher,F_tiefer)
# Out:
# <audio controls="controls" {autoplay}>
# <source src="SinustonAB1A2a.wav" type="audio/wav" />
# Your browser does not support the audio element.
# </audio>

# %% [markdown]
# ## Aufgabe 2b)
# Wir betrachten wieder
# $$ g(t) = \sin(F(t) \cdot 200 \cdot 2\pi \cdot t), \ t \geq 0.$$
#                                                                                                                                   Diesmal ist $F$ jedoch keine Konstante, sondern ebenfalls von $t$ Abhängig. Wie musst der Term für $F(t)$  aussehen, damit die Frequenz des Audiosignals $g$ linear wächst, das Signal $g$ zum Zeitpunkt $t = 0$ eine Frequenz von 200 Hz besitzt und zum Zeitpunkt $t = 0.1$ eine Frequnz von 400 Hz besitzt?
#
# *Ersetze im folgenden Code `NaN`, durch einen Term in $t$, sodass der zeitabhängige Faktor $F(t)$ linear steigt und das Signal $g$ (s.o.) zum Zeitpunkt $t = 0$ eine Frequenz von 200 Hz besitzt und zum Zeitpunkt $t = 0.1$ eine Frequenz von 400 Hz. Klicke anschließend "Run", um dir den Ton anzuhören und anzusehen. Falls deine Eingabe fehlerhaft ist, bekommst du eine Warnung. Korrigiere dich in diesem Fall.*
#
# **Achtung: Da sich die Frequenz von g mit der Zeit ändert, handelt es sich bei g nicht mehr um einen (reinen) Ton!**

# %%
F(t) = 10t+1; # Ersetze 'NaN' durch einen Term in t, sodass die resultierende Frequenz F(t) linear wächst und der Ton g bei t = 0 bzw. t = 0.1 eine Frequenz von 200 Hz bzw. 400 Hz besitzt.           

# Ab hier nichts mehr ändern
Shazam.AB1A2bPlay(F)
Shazam.AB1Aufgabe2b(F)
# Out:
# <audio controls="controls" {autoplay}>
# <source src="SinustonAB1A2b.wav" type="audio/wav" />
# Your browser does not support the audio element.
# </audio>

# %% [markdown]
# ## Aufgabe 3)
# Am Ende des Tages wird das Ziel sein, ein von einer anderen Gruppe erstelltes Audiosignal mit Hilfe des Shazam-Algorithmus zu identifizieren. Dazu sollt ihr jetzt euer eigenes Audiosignal erstellen, das nachher anderen Gruppen zur Verfügung gestellt wird. Euer Audiosignal soll die Summe mehrerer Sinusschwingungen sein, deren Frequenzen ruhig von der Zeit abhängen dürfen. Ein Beispiel für ein aus drei Sinusschwingungen zusammengesetztes Signal seht ihr hier:
# $$ g(t) = 3 \sin(2000 \cdot 2\pi \cdot t) + 0.5 \sin(4100 \cdot 2\pi \cdot t) + \sin(1000 \cdot 2\pi \cdot (t-2)^2).$$
# *Um euer Audiosignal zu speichern, ersetzt ihr im folgenden Code `NaN` durch eure Gruppennummer. Diese findet ihr auf eurem Platz. Denkt euch nun für euer Audiosignal einen Songtitel und einen Interpreten aus, die ihr jeweils unter `Songtitel` und `Interpret` im Code eintragt. Das Zeitintervall, auf dem ihr euer eigenes kleines Musikstück betrachten wollt, könnt ihr mit `a` (Untergrenze) und `b` (Obergrenze) festlegen. Die Zeit $t$ liegt dann im Intervall $[a, b]$. Ersetzt zum Schluss das letzte `NaN` im Code durch die Summe dreier Sinusschwingungen - das ist dann euer "Song".  Mit "Run Section" wird euer Audiosignal abgespielt, graphisch angezeigt und als Datei im Ordner `Arbeitsblatt 1` unter dem Ordner `Euer_Sound` gespeichert.*

# %%
# Hier benötigen wir den Server
Gruppennummer = NaN; # Ersetze 'NaN' durch deine Gruppennummer
Songtitel = " "; # Trage deinen Songtitel zwischen den Anführungszeichen ein
Interpret = " "; # Trage deinen Interpreten zwischen den Anführungszeichen ein

a = NaN; # Ersetze 'NaN' durch deine untere Intervallgrenze
b = NaN; # Ersetze 'NaN' durch deine obere Intervallgrenze

y(t) = NaN; # Ersetze 'NaN' durch einen Funktionsterm, welcher dein Audiosignal beschreibt

# %% [markdown]
# ## Zusatzaufgabe A
# In Aufgabe 1 haben wir Töne mit wachsenden oder fallenden Amplituden erzeugt. Nun wollen wir Töne erzeugen, deren Amplitude zunächst fällt und anschließend wieder wächst. Das heißt, Töne, die erst leiser und dann wieder lauter werden. Der Zeitpunkt $t_{min}$, an dem die Amplitude ihr Minimum annimmt, also der Zeitpunkt, an dem die Steigung ihr Vorzeichen wechselt, darf von dir selber bestimmt werden, du musst diesen jedoch angeben. Außerdem kannst du nun selber das Intervall bestimmen, in dem du dir den Graph des Tons anschauen möchtest. Du musst allerdings darauf achten, dass $t_{min}$ in diesem Intervall liegt, damit du den Verlauf der Amplitude richtig erkennen kannst.
#
# *Ersetze im folgenden Code `NaN` durch einen Term in $t$, sodass die Amplitude $A4$ deines Tons zunächst fällt und dann wieder steigt. Gebe dann den Zeitpunkt `t_min` an, an dem die Amplitude minimal ist. Das Intervall, auf dem du den Ton betrachten möchtest kannst du mit `a` (Untergrenze) und `b` (Obergrenze) festlegen. Klicke anschließend auf "Run". Dann kannst du deinen Ton hören und sehen. Falls deine Eingabe falsch ist, bekommst du eine Warnung angezeigt. Korrigiere dich in diesem Fall.*
#
# **Hinweis: Falls du beim Lösen dieser Aufgabe Hilfe benötigst, siehe dir [Hilfekarte 2](./ShazamHilfekarte2.ipynb) an.**

# %%
A4(t) = t^2; # Ersetze NaN durch einen Term in t, sodass A4 eine zunächst fallende und dann wachsende Amplitude beschreibt
t_min = 0; # Ersetze NaN durch den Zeitpunkt, an dem die Amplitude A4 minimal ist
a = -0.05; # Ersetze NaN durch die untere Intervallgrenze des Intervalls, das du betrachten möchtest (t_min soll in diesem Intervall liegen)
b = 0.05; # Ersetze NaN durch die obere Intervallgrenze des Intervalls, das du betrachten möchtest (t_min soll in diesem Intervall liegen)

# Ab hier nichts mehr ändern
Shazam.AB1ZAPlay(A4,a,b)
Shazam.AB1ZusatzaufgabeA(A4,t_min,a,b)
# Out:
# <audio controls="controls" {autoplay}>
# <source src="SinustonAB1A2b.wav" type="audio/wav" />
# Your browser does not support the audio element.
# </audio>

# %% [markdown]
# ## Zusatzaufgabe B
# Wähle die Amplitude nun so, dass die Lautstärke zuerst 0 beträgt, dann bis zu einem Zeitpunkt $t_{max}$ wächst und ab $t_{max}$ wieder auf 0 fällt. Um diesen Effekt besser hören zu können, wird die Frequenz auf 50 Hz gesetzt. Die beiden Nullstellen deiner Amplitude (Anfang und Ende des Tons) und den Zeitpunkt der maximalen Amplitude $t_{max}$ kannst du frei wählen. Du musst diese jedoch angeben.
#
# *Ersetze im folgenden Code `NaN` durch einen Term in $t$, der eine zunächst wachsende und dann fallende Amplitude $A5$ beschreibt. Trage für `t_max` den Zeitpunkt ein, zu dem die Amplitude $A5$ maximal ist. Trage für `a` den Zeitpunkt ein, an dem die Amplitude $A5$ das erste Mal den Wert Null annimmt, also den Beginn deines Tons. Trage für `b` den Zeitpunkt ein, an dem die Amplitude $A5$ das zweite Mal den Wert 0 annimmt, also das Ende deines Tons. Klicke dann auf "Run", um das Resultat zu sehen und zu hören. Wenn deine Eingabe fahlerhaft ist, bekommst du eine Warnung. Korrigiere dich in diesem Fall.*
#
# **Hinweis: Falls du beim Lösen dieser Aufgabe Hilfe benötigst, siehe dir [Hilfekarte3](./ShazamHilfekarte3.ipynb) an.**

# %%
A5(t) = 20*(-t^2+0.5^2); # Ersetze 'NaN' hier durch einen Term in t, sodass die Amplitude A5 zunächst wächst und dann fällt
t_max = 0; # Ersetze 'NaN' durch den Zeitpunkt, zu dem die Amplitude A5 maximal ist
a = -0.5; # Ersetze 'NaN' durch den Zeitpunkt, an dem die Amplitude A5 zum ersten Mal den Wert 0 hat (Anfang des Tons)
b = 0.5; # Ersetze NaN durch den Zeitpunkt, an dem die Amplitude A5 zum zweiten Mal den Wert 0 hat (Ende des Tons)

# Ab hier nichts mehr ändern
Shazam.AB1ZBPlay(A5,a,b)
Shazam.AB1ZusatzaufgabeB(A5,t_max,a,b)
# Out:
# <audio controls="controls" {autoplay}>
# <source src="SinustonAB1ZB.wav" type="audio/wav" />
# Your browser does not support the audio element.
# </audio>

# %% [markdown]
# ## Zusatzaufgabe C
# Jetzt betrachten wir noch einmal Sinusschwingungen deren Frequenz sich mit der Zeit ändert, also Signale der Form
# $$g(t) = \sin(F(t) \cdot 200 \cdot 2\pi \cdot t).$$                                                                                                                                        Überlege dir, wie du den zeitabhängigen Faktor $F(t)$ wählen musst, damit das Signal $g$ mit der Zeit tiefer wird. Das Intervall, auf dem du das Signal betrachten möchtest, kannst du ebenfalls frei wählen.
#
# *Trage im folgenden Code die Intervallgrenzen `a` (Untergrenze) und `b` (Obergrenze) des Intervalls ein, auf dem du dein Signal betrachten möchtest. Ersetze dann `NaN` durch einen Term in $t$, sodass das Signal $g$ (s.o.) auf dem von dir gewählten Intervall tiefer wird. Klicke auf "Run", um dein Signal zu sehen und zu hören. Wenn deine Eingabe fehlerhaft ist, bekommst du eine Warnung. Korrigiere dich in diesem Fall.*
#
# **Hinweis: Beachtet die Punktsymmetrie vom Sinus, sodass gilt: sin(-x) = -sin(x).**

# %%
a = 0; # Ersetze 'NaN' durch die untere Intervallgrenze des Intervalls, das du betrachten möchtest
b = 0.1; # Ersetze 'NaN' durch die obere Intervallgrenze des Intervalls, das du betrachten möchtest
F(t) = 1-t*5; # Ersetze 'NaN' durch einen Term in t, sodass das Signal g auf dem von dir ausgewählten Intervall tiefer wird

# Ab hier nichts mehr ändern
Shazam.AB1ZCPlay(a,F)
Shazam.AB1ZusatzaufgabeC(a,b,F)
# Out:
# <audio controls="controls" {autoplay}>
# <source src="SinustonAB1ZC.wav" type="audio/wav" />
# Your browser does not support the audio element.
# </audio>

# %% [markdown]
# ## Zusatzaufgabe D
# Wir betrachten wieder
# $$ g(t)= \sin(F(t) \cdot 200 \cdot 2\pi \cdot t).$$
# Überlege dir, wie du den von $t$ abhängigen Faktor $F(t)$ wählen musst, damit das Signal $g$ mit der Zeit erst tiefer und dann wieder höher wird. Das Intervall, auf dem du dein Signal betrachten möchtest, kann ebenfalls von dir bestimmt werden.
#
# *Trage im folgenden Code die Intervallgrenzen `a` (Untergrenze) und `b` (Obergrenze) des Intervalls ein, auf dem du dein Signal betrachten möchtest. Ersetze dann `NaN` durch einen Term in $t$, sodass das Signal $g$ (s.o.) auf dem von dir gewählten Intervall erst tiefer wird und dann wieder höher wird. Klicke auf "Run", um dein Signal zu sehen und zu hören. Falls deine Eingabe fehlerhaft ist, bekommst du eine Warnung. Korrigiere dich in diesem Fall.*

# %%
a = 0; # Ersetze 'NaN' durch die untere Intervallgrenze des Intervalls, das du betrachten möchtest
b = 1; # Ersetze 'NaN' durch die obere Intervallgrenze des Intervalls, das du betrachten möchtest
F(t) = 2*(t-0.75)^2+0.5; # Ersetze 'NaN' durch einen Term in t, sodass das Signal g auf dem von dir ausgewählten Intervall erst tiefer und dann wieder höher wird

# Ab hier nichts mehr ändern
Shazam.AB1ZDPlay(a,b,F)
Shazam.AB1ZusatzaufgabeD(a,b,F)
# Out:
# <audio controls="controls" {autoplay}>
# <source src="SinustonAB1ZD.wav" type="audio/wav" />
# Your browser does not support the audio element.
# </audio>
